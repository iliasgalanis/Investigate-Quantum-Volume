# %% [markdown]
# ## This is the 4x5 experiment for ibmq_belem. The circuit is transpiled to a 4x7 circuit.

# %%
import numpy as np
# Importing standard Qiskit libraries
from qiskit import *
from qiskit.tools.jupyter import *
from qiskit.visualization import *

# %%
#define the number of qubits - width
width = 4


# define a quantum register with four qubits
q =  QuantumRegister(width,"qreg")

# define a classical register with one bit
# it stores the measurement result of the quantum part
c = ClassicalRegister(width,"creg")

# define our quantum circuit
qc = QuantumCircuit(q,c)

qc.h(0)


qc.cx(0,1)
qc.cx(1,2)
qc.cx(2,3)

# measure the first qubit, and store the result in the first classical bit
qc.measure(q,c)

# draw the circuit by using matplotlib
qc.draw(output='mpl') # re-run the cell if the figure is not displayed

# %%
qc.depth()
# Out:
# 5

# %%
# execute the circuit 10000 times in the local simulator

job = execute(qc,Aer.get_backend('qasm_simulator'),shots=10000)
counts = job.result().get_counts(qc)
print(counts) # print the outcomes

# we can show the result by using histogram
print()
from qiskit.visualization import plot_histogram
plot_histogram(counts)
# Out:
# {'1111': 5043, '0000': 4957}

# %%
# Loading your IBM Quantum account(s)
provider = IBMQ.load_account()

provider = IBMQ.get_provider("ibm-q")
#using this tool to monitor our position in queue
from qiskit.tools.monitor import job_monitor

#choose real device
backend = provider.get_backend('ibmq_belem')

# %% [markdown]
# ### Run the circuit with optimization_level = 1

# %%
qc_transpiled = transpile(qc, backend, optimization_level=1)
print("The TRANSPILED circuit depth is:", qc_transpiled.depth())
# Out:
# The TRANSPILED circuit depth is: 7

# %%
qc_transpiled.draw(output='mpl')

# %%
shots = 1024
job = execute(qc, backend= backend, name="Exp_4x5_ibmq_belem_opt_level=1" , shots= shots)
job_monitor(job)
# Out:
# C:\Users\ilias\Anaconda3\lib\site-packages\qiskit\execute_function.py:343: UserWarning: name is not a recognized runtime option and may be ignored by the backend.
#   job = backend.run(experiments, **run_kwargs)
# Job Status: job has successfully run

# %%
results = job.result()
answer = results.get_counts()

plot_histogram(answer)

# %% [markdown]
# ### Run the circuit with optimization_level = 2

# %%
qc_transpiled = transpile(qc, backend, optimization_level=2)
print("The TRANSPILED circuit depth is:", qc_transpiled.depth())
# Out:
# The TRANSPILED circuit depth is: 7

# %%
qc_transpiled.draw(output='mpl')

# %%
shots = 1024
job = execute(qc, backend= backend, name="Exp_4x5_ibmq_belem_opt_level=2" , shots= shots)
job_monitor(job)
# Out:
# Job Status: job has successfully run

# %%
results = job.result()
answer = results.get_counts()

plot_histogram(answer)

# %% [markdown]
# ### Run the circuit with optimization_level = 3

# %%
qc_transpiled = transpile(qc, backend, optimization_level=3)
print("The TRANSPILED circuit depth is:", qc_transpiled.depth())
# Out:
# The TRANSPILED circuit depth is: 7

# %%
qc_transpiled.draw(output='mpl')

# %%
shots = 1024
job = execute(qc, backend= backend, name="Exp_4x5_ibmq_belem_opt_level=3" , shots= shots)
job_monitor(job)
# Out:
# Job Status: job has successfully run

# %%
results = job.result()
answer = results.get_counts()

plot_histogram(answer)
