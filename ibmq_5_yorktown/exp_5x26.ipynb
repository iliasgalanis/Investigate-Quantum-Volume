# %% [markdown]
# ## This is exp 5x26 for ibmq_5_yorktown. The initial circuit is 5x6 which is then traspiled to 5x22. Only H and CNOT, CCNOT and X gates are used.

# %%
import numpy as np
# Importing standard Qiskit libraries
from qiskit import *
from qiskit.tools.jupyter import *
from qiskit.visualization import *

# %%
#define the number of qubits - width
width = 5

#define the quantum register
q =  QuantumRegister(width,"qreg")

# define a classical register
# it stores the measurement result of the quantum part
c = ClassicalRegister(width,"creg")

# define our quantum circuit
qc = QuantumCircuit(q,c)

qc.h(0)
qc.h(2)

qc.cx(0,1)
qc.cx(1,4)
qc.cx(2,3)
qc.barrier()
qc.ccx(3,4,1)
qc.x(1)
qc.barrier()

# measure the first qubit, and store the result in the first classical bit
qc.measure(q,c)

# draw the circuit by using matplotlib
qc.draw(output='mpl') # re-run the cell if the figure is not displayed

# %%
qc.depth()
# Out:
# 6

# %%
# execute the circuit 10000 times in the local simulator

job = execute(qc,Aer.get_backend('qasm_simulator'),shots=10000)
counts = job.result().get_counts(qc)
print(counts) # print the outcomes

# we can show the result by using histogram
print()
from qiskit.visualization import plot_histogram
plot_histogram(counts)
# Out:
# {'10001': 2507, '11111': 2499, '00010': 2472, '01110': 2522}

# %%
# Loading your IBM Quantum account(s)
provider = IBMQ.load_account()

provider = IBMQ.get_provider("ibm-q")
#using this tool to monitor our position in queue
from qiskit.tools.monitor import job_monitor

#choose real device
backend = provider.get_backend('ibmq_5_yorktown')

# %%
backend.configuration().basis_gates
# Out:
# ['id', 'rz', 'sx', 'x', 'cx', 'reset']

# %% [markdown]
# ### Run the circuit with optimization_level = 1

# %%
qc_transpiled = transpile(qc, backend, optimization_level=1)
print("The TRANSPILED circuit depth is:", qc_transpiled.depth())
# Out:
# The TRANSPILED circuit depth is: 22

# %%
qc_transpiled.draw(output='mpl')

# %%
shots = 1024
job = execute(qc, backend= backend, shots= shots)
job_monitor(job)
# Out:
# Job Status: job has successfully run

# %%
results = job.result()
answer = results.get_counts()
counts = job.result().get_counts(qc_transpiled)
print(counts) # print the outcomes


plot_histogram(answer)
# Out:
# {'00000': 51, '00001': 38, '10000': 57, '10001': 77, '10010': 52, '10011': 27, '10100': 16, '10101': 26, '10110': 32, '10111': 13, '11000': 20, '11001': 19, '11010': 36, '11011': 32, '11100': 21, '11101': 19, '11110': 42, '11111': 45, '00010': 108, '00011': 13, '00100': 21, '00101': 25, '00110': 39, '00111': 16, '01000': 16, '01001': 11, '01010': 30, '01011': 15, '01100': 22, '01101': 13, '01110': 52, '01111': 20}

# %% [markdown]
# as expected the hight depth of the circuit highly affects the outcome and no usefull conclusion can be made on which is the right outcome

# %% [markdown]
# ### Run the circuit with optimization_level = 2

# %%
qc_transpiled = transpile(qc, backend, optimization_level=2)
print("The TRANSPILED circuit depth is:", qc_transpiled.depth())
# Out:
# The TRANSPILED circuit depth is: 27

# %%
qc_transpiled.draw(output='mpl')

# %%
shots = 1024
job = execute(qc, backend= backend, shots= shots)
job_monitor(job)
# Out:
# Job Status: job has successfully run

# %%
results = job.result()
answer = results.get_counts()
counts = job.result().get_counts(qc_transpiled)
print(counts) # print the outcomes


plot_histogram(answer)
# Out:
# {'00000': 71, '00001': 22, '10000': 23, '10001': 81, '10010': 49, '10011': 49, '10100': 16, '10101': 34, '10110': 26, '10111': 32, '11000': 21, '11001': 7, '11010': 14, '11011': 25, '11100': 28, '11101': 22, '11110': 34, '11111': 85, '00010': 77, '00011': 17, '00100': 21, '00101': 15, '00110': 41, '00111': 19, '01000': 16, '01001': 4, '01010': 34, '01011': 7, '01100': 42, '01101': 10, '01110': 68, '01111': 14}

# %% [markdown]
# ### Run the circuit with optimization_level = 3

# %%
qc_transpiled = transpile(qc, backend, optimization_level=3)
print("The TRANSPILED circuit depth is:", qc_transpiled.depth())
# Out:
# The TRANSPILED circuit depth is: 42

# %%
qc_transpiled.draw(output='mpl')

# %%
shots = 1024
job = execute(qc, backend= backend, shots= shots)
job_monitor(job)
# Out:
# Job Status: job has successfully run

# %%
results = job.result()
answer = results.get_counts()
counts = job.result().get_counts(qc_transpiled)
print(counts) # print the outcomes


plot_histogram(answer)
# Out:
# {'00000': 30, '00001': 16, '10000': 31, '10001': 124, '10010': 35, '10011': 38, '10100': 6, '10101': 28, '10110': 7, '10111': 13, '11000': 9, '11001': 25, '11010': 13, '11011': 23, '11100': 19, '11101': 56, '11110': 27, '11111': 63, '00010': 165, '00011': 9, '00100': 18, '00101': 3, '00110': 21, '00111': 15, '01000': 10, '01001': 14, '01010': 26, '01011': 8, '01100': 50, '01101': 7, '01110': 101, '01111': 14}
